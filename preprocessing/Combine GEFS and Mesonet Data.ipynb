# %% [markdown]
# # Combine GEFS and Mesonet Data
#
# Notebook to preprocess the GEFS data and combine it with the Mesonet solar station data, into a single data file for use in the modelling process

# %%
import xarray as xr
import pandas as pd

from collections import OrderedDict
from math import radians, cos, sin, asin, sqrt

# %% [markdown]
# ### GEFS Prediction Data
#
# Load the consolidated GEFS training data and create the new forecast_datetime feature (actual end date datetime corresponding to the numberical prediction for the prior 3 hour period back from the end date value)

# %%
gefs_train_df = pd.read_csv("../data/gefs/gefs_train_daily.csv")
gefs_train_df.head()
# Out:
#     lat    lon        time  Upward_Long-Wave_Rad_Flux_surface mean  \
# 0  31.0  254.0  1994-01-01                              367.065219
# 1  31.0  254.0  1994-01-02                              368.057103
# 2  31.0  254.0  1994-01-03                              358.022946
# 3  31.0  254.0  1994-01-04                              366.386096
# 4  31.0  254.0  1994-01-05                              372.722521
#
#    Upward_Long-Wave_Rad_Flux_surface min  \
# 0                              324.00000
# 1                              329.00000
# 2                              309.02200
# 3                              318.54144
# 4                              321.57993
#
#    Upward_Long-Wave_Rad_Flux_surface std  \
# 0                              40.295247
# 1                              36.823085
# 2                              44.284551
# 3                              42.917750
# 4                              48.962837
#
#    Upward_Long-Wave_Rad_Flux_surface max  Upward_Short-Wave_Rad_Flux mean  \
# 0                              422.75583                        68.781818
# 1                              419.00000                        69.690909
# 2                              418.46637                        70.036364
# 3                              426.78842                        69.727273
# 4                              436.33432                        70.581818
#
#    Upward_Short-Wave_Rad_Flux min  Upward_Short-Wave_Rad_Flux std  \
# 0                             0.0                       63.209438
# 1                             0.0                       64.501184
# 2                             0.0                       64.539383
# 3                             0.0                       64.255985
# 4                             0.0                       65.015010
#
#        ...       Upward_Long-Wave_Rad_Flux std  Upward_Long-Wave_Rad_Flux max  \
# 0      ...                           11.482474                      281.09550
# 1      ...                            9.825419                      278.86664
# 2      ...                           17.336351                      279.30950
# 3      ...                           13.590242                      282.80730
# 4      ...                           14.535518                      289.41656
#
#    ens mean  ens min   ens std  ens max  Pressure mean  Pressure min  \
# 0         5        0  3.191424       10  102217.904727     101916.42
# 1         5        0  3.191424       10  102173.175091     101924.96
# 2         5        0  3.191424       10  102152.114182     101812.38
# 3         5        0  3.191424       10  102382.628545     102041.37
# 4         5        0  3.191424       10  101443.177091     100905.18
#
#    Pressure std  Pressure max
# 0    184.451255     102476.81
# 1    153.622300     102467.37
# 2    241.888780     102459.32
# 3    166.193135     102632.57
# 4    379.803869     101964.53
#
# [5 rows x 67 columns]

# %% [markdown]
# ### GEFS Grid Elevation Data
#
# Load the elevation data on each of the GEFS grid simulation points

# %%
gefs_elevation_df = xr.open_dataset("../data/gefs/gefs_elevations.nc").to_dataframe().reset_index()
gefs_elevation_df.head()
# Out:
#    lat  lon  elevation_control  elevation_perturbation  latitude  longitude
# 0    0    0        1420.699219             1342.618286      31.0      254.0
# 1    0    1        1346.989990             1328.494019      31.0      255.0
# 2    0    2        1323.471436             1244.265381      31.0      256.0
# 3    0    3         878.612122              919.849365      31.0      257.0
# 4    0    4         801.242798              821.093567      31.0      258.0

# %% [markdown]
# ### Mesonet Solar Energy Readings
#
# Load the historical daily Mesonet solar station energy reading

# %%
mesonet_readings_df = pd.read_csv("../data/mesonet/train.csv")
mesonet_readings_df.head()
# Out:
#        Date      ACME      ADAX      ALTU      APAC      ARNE      BEAV  \
# 0  19940101  12384900  11930700  12116700  12301200  10706100  10116900
# 1  19940102  11908500   9778500  10862700  11666400   8062500   9262800
# 2  19940103  12470700   9771900  12627300  12782700  11618400  10789800
# 3  19940104  12725400   6466800  13065300  12817500  12134400  11816700
# 4  19940105  10894800  11545200   8060400  10379400   6918600   9936300
#
#        BESS      BIXB      BLAC    ...         VINI      WASH      WATO  \
# 0  11487900  11182800  10848300    ...     10771800  12116400  11308800
# 1   9235200   3963300   3318300    ...      4314300  10733400   9154800
# 2  11895900   4512600   5266500    ...      2976900  11775000  10700400
# 3  12186600   3212700   8270100    ...      3476400  12159600  11907000
# 4   6411300   9566100   8009400    ...      6393300  11419500   7334400
#
#        WAUR      WEAT      WEST      WILB      WIST      WOOD      WYNO
# 0  12361800  11331600  10644300  11715600  11241000  10490100  10545300
# 1  12041400   9168300   4082700   9228000   5829900   7412100   3345300
# 2  12687300  11324400   2746500   3686700   4488900   9712200   4442100
# 3  12953100  11903700   2741400   4905000   4089300  11401500   4365000
# 4  10178700   7471500   8235300  11159100  10651500  10006200   8568300
#
# [5 rows x 99 columns]

# %% [markdown]
# ### Mesonet Station Coordinates
#
# Load the information on each Mesonet solar station. As noted in the Kaggle challenge data description, we need to transform the longitude of the Mesonet station data to coincide with the same origin or meridian reference by adding 360 degrees to the existing longitude.

# %%
mesonet_stations_df = pd.read_csv("../data/mesonet/station_info.csv")
mesonet_stations_df["elon_corrected"] = mesonet_stations_df["elon"] + 360
mesonet_stations_df.head()
# Out:
#    stid      nlat      elon  elev  elon_corrected
# 0  ACME  34.80833 -98.02325   397       261.97675
# 1  ADAX  34.79851 -96.66909   295       263.33091
# 2  ALTU  34.58722 -99.33808   416       260.66192
# 3  APAC  34.91418 -98.29216   440       261.70784
# 4  ARNE  36.07204 -99.90308   719       260.09692

# %% [markdown]
# ### Combining Mesonet and GEFS Data
#
# For simiplicity, we'll link together the Mesonet and GEFS data by matching each Mesonet station together with the closest GEFS grid point. The closest GEFS grid point will be determined by using the haversine formula to compute the great circle distance between each Mesonet station and each GEFS grid point, and choosing the closest grid point with the minimal distance.

# %%
def df_crossjoin(df1_, df2_, **kwargs):
    """
    Author: Markus Konrad <post@mkonrad.net>
    April 2016
    Make a cross join (cartesian product) between two dataframes by using a constant temporary key.
    Also sets a MultiIndex which is the cartesian product of the indices of the input dataframes.
    See: https://github.com/pydata/pandas/issues/5401
    :param df1 dataframe 1
    :param df1 dataframe 2
    :param kwargs keyword arguments that will be passed to pd.merge()
    :return cross join of df1 and df2
    """
    df1 = df1_.copy(deep=True)
    df2 = df2_.copy(deep=True)
    
    df1['_tmpkey'] = 1
    df2['_tmpkey'] = 1

    res = pd.merge(df1, df2, on='_tmpkey', **kwargs).drop('_tmpkey', axis=1)
    res.index = pd.MultiIndex.from_product((df1.index, df2.index))

    df1.drop('_tmpkey', axis=1, inplace=True)
    df2.drop('_tmpkey', axis=1, inplace=True)

    return res


def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles
    return c * r

# %%
gefs_grid_coords_df = gefs_elevation_df[["latitude", "longitude", "elevation_control", "elevation_perturbation"]]
gefs_grid_coords_df.columns = ["gefs_lat", "gefs_lon", "elevation_control", "elevation_perturbation"]

# %% [markdown]
# Form the cartesian production between the coordinates of all the Mesonet stations and the GEFS grid points

# %%
distances_df = df_crossjoin(
    mesonet_stations_df, 
    gefs_grid_coords_df, 
    suffixes=('_orig', '_dest')
).reset_index(drop=True)
distances_df.head()
# Out:
#    stid      nlat      elon  elev  elon_corrected  gefs_lat  gefs_lon  \
# 0  ACME  34.80833 -98.02325   397       261.97675      31.0     254.0
# 1  ACME  34.80833 -98.02325   397       261.97675      31.0     255.0
# 2  ACME  34.80833 -98.02325   397       261.97675      31.0     256.0
# 3  ACME  34.80833 -98.02325   397       261.97675      31.0     257.0
# 4  ACME  34.80833 -98.02325   397       261.97675      31.0     258.0
#
#    elevation_control  elevation_perturbation
# 0        1420.699219             1342.618286
# 1        1346.989990             1328.494019
# 2        1323.471436             1244.265381
# 3         878.612122              919.849365
# 4         801.242798              821.093567

# %% [markdown]
# Compute all the great circle distances between the stations and grid points

# %%
distances_df["distance_km"] = distances_df.apply(
    lambda x: haversine(
        x["elon_corrected"],
        x["nlat"],
        x["gefs_lon"],
        x["gefs_lat"]
    ), 
    axis=1
)
distances_df.head()
# Out:
#    stid      nlat      elon  elev  elon_corrected  gefs_lat  gefs_lon  \
# 0  ACME  34.80833 -98.02325   397       261.97675      31.0     254.0
# 1  ACME  34.80833 -98.02325   397       261.97675      31.0     255.0
# 2  ACME  34.80833 -98.02325   397       261.97675      31.0     256.0
# 3  ACME  34.80833 -98.02325   397       261.97675      31.0     257.0
# 4  ACME  34.80833 -98.02325   397       261.97675      31.0     258.0
#
#    elevation_control  elevation_perturbation  distance_km
# 0        1420.699219             1342.618286   856.245389
# 1        1346.989990             1328.494019   776.560630
# 2        1323.471436             1244.265381   700.224888
# 3         878.612122              919.849365   628.467824
# 4         801.242798              821.093567   563.050404

# %% [markdown]
# For each Mesonet station, select the closest grid point

# %%
def get_closest_grid_point(group):
    "Find the closest grid point for a given station group"
    
    group_sorted = group.sort_values("distance_km", ascending=False)
    
    ret = pd.Series(OrderedDict([
        ("meso_lat", group_sorted.iloc[0]["nlat"]),
        ("meso_lon", group_sorted.iloc[0]["elon_corrected"]),
        ("meso_elev", group_sorted.iloc[0]["elev"]),
        ("gefs_lat", group_sorted.iloc[0]["gefs_lat"]),
        ("gefs_lon", group_sorted.iloc[0]["gefs_lon"]),
        ("gefs_elev", group_sorted.iloc[0]["elevation_control"]),
        ("distance_km", group_sorted.iloc[0]["distance_km"])
    ]))
    
    return ret
    

mesonet_gefs_matches_df = (
    distances_df
    .groupby("stid")
    .apply(lambda x: get_closest_grid_point(x))
).reset_index()
mesonet_gefs_matches_df.head()
# Out:
#    stid  meso_lat   meso_lon  meso_elev  gefs_lat  gefs_lon    gefs_elev  \
# 0  ACME  34.80833  261.97675      397.0      31.0     254.0  1420.699219
# 1  ADAX  34.79851  263.33091      295.0      31.0     254.0  1420.699219
# 2  ALTU  34.58722  260.66192      416.0      39.0     269.0   195.383102
# 3  APAC  34.91418  261.70784      440.0      31.0     254.0  1420.699219
# 4  ARNE  36.07204  260.09692      719.0      31.0     269.0    84.810104
#
#    distance_km
# 0   856.245389
# 1   967.568287
# 2   889.345616
# 3   840.192442
# 4   998.778385

# %% [markdown]
# With the mapping in hand, now join the Mesonet data back with the GEFS data. First, we need to reorient the Mesonet solar readings data.

# %%
mesonet_readings_melt_df = pd.melt(mesonet_readings_df, id_vars=['Date'], var_name='station', value_name='value')
mesonet_readings_melt_df.columns = ["datetime", "station", "measured_solar_output"]
mesonet_readings_melt_df.head()
# Out:
#    datetime station  measured_solar_output
# 0  19940101    ACME               12384900
# 1  19940102    ACME               11908500
# 2  19940103    ACME               12470700
# 3  19940104    ACME               12725400
# 4  19940105    ACME               10894800

# %% [markdown]
# We'll want to join the Mesonet readings with the GEFS using the time variable. Let's reformat that in the GEFS data to be in the same format as the Mesonet data. This can be a little slow.

# %%
gefs_train_df["datetime"] = pd.to_datetime(gefs_train_df["time"]).dt.strftime("%Y%m%d")
gefs_train_df.head()
# Out:
#     lat    lon        time  Upward_Long-Wave_Rad_Flux_surface mean  \
# 0  31.0  254.0  1994-01-01                              367.065219
# 1  31.0  254.0  1994-01-02                              368.057103
# 2  31.0  254.0  1994-01-03                              358.022946
# 3  31.0  254.0  1994-01-04                              366.386096
# 4  31.0  254.0  1994-01-05                              372.722521
#
#    Upward_Long-Wave_Rad_Flux_surface min  \
# 0                              324.00000
# 1                              329.00000
# 2                              309.02200
# 3                              318.54144
# 4                              321.57993
#
#    Upward_Long-Wave_Rad_Flux_surface std  \
# 0                              40.295247
# 1                              36.823085
# 2                              44.284551
# 3                              42.917750
# 4                              48.962837
#
#    Upward_Long-Wave_Rad_Flux_surface max  Upward_Short-Wave_Rad_Flux mean  \
# 0                              422.75583                        68.781818
# 1                              419.00000                        69.690909
# 2                              418.46637                        70.036364
# 3                              426.78842                        69.727273
# 4                              436.33432                        70.581818
#
#    Upward_Short-Wave_Rad_Flux min  Upward_Short-Wave_Rad_Flux std    ...     \
# 0                             0.0                       63.209438    ...
# 1                             0.0                       64.501184    ...
# 2                             0.0                       64.539383    ...
# 3                             0.0                       64.255985    ...
# 4                             0.0                       65.015010    ...
#
#    Upward_Long-Wave_Rad_Flux max  ens mean  ens min   ens std  ens max  \
# 0                      281.09550         5        0  3.191424       10
# 1                      278.86664         5        0  3.191424       10
# 2                      279.30950         5        0  3.191424       10
# 3                      282.80730         5        0  3.191424       10
# 4                      289.41656         5        0  3.191424       10
#
#    Pressure mean  Pressure min  Pressure std  Pressure max  datetime
# 0  102217.904727     101916.42    184.451255     102476.81  19940101
# 1  102173.175091     101924.96    153.622300     102467.37  19940102
# 2  102152.114182     101812.38    241.888780     102459.32  19940103
# 3  102382.628545     102041.37    166.193135     102632.57  19940104
# 4  101443.177091     100905.18    379.803869     101964.53  19940105
#
# [5 rows x 68 columns]

# %% [markdown]
# First combine the Mesonet solar readings and the matched GEFS grid points

# %%
tmp_1_df = pd.merge(
    mesonet_readings_melt_df,
    mesonet_gefs_matches_df,
    left_on="station",
    right_on="stid",
    how="left"
)
tmp_1_df["gefs_lat"] = tmp_1_df["gefs_lat"].astype(float)
tmp_1_df["gefs_lon"] = tmp_1_df["gefs_lon"].astype(float)
tmp_1_df["datetime"] = tmp_1_df["datetime"].astype(int)
tmp_1_df.head()
# Out:
#    datetime station  measured_solar_output  stid  meso_lat   meso_lon  \
# 0  19940101    ACME               12384900  ACME  34.80833  261.97675
# 1  19940102    ACME               11908500  ACME  34.80833  261.97675
# 2  19940103    ACME               12470700  ACME  34.80833  261.97675
# 3  19940104    ACME               12725400  ACME  34.80833  261.97675
# 4  19940105    ACME               10894800  ACME  34.80833  261.97675
#
#    meso_elev  gefs_lat  gefs_lon    gefs_elev  distance_km
# 0      397.0      31.0     254.0  1420.699219   856.245389
# 1      397.0      31.0     254.0  1420.699219   856.245389
# 2      397.0      31.0     254.0  1420.699219   856.245389
# 3      397.0      31.0     254.0  1420.699219   856.245389
# 4      397.0      31.0     254.0  1420.699219   856.245389

# %% [markdown]
# Before we combine the Mesonet and GEFS data, we need to make the GEFS data be on the daily level

# %% [markdown]
# Now combine the daily GEFS data with the daily Mesonet data, using the coorindates and timestamp from the matching

# %%
gefs_train_df["lat"] = gefs_train_df["lat"].astype(float)
gefs_train_df["lon"] = gefs_train_df["lon"].astype(float)
gefs_train_df["datetime"] = gefs_train_df["datetime"].astype(int)
gefs_train_df.head()
# Out:
#     lat    lon        time  Upward_Long-Wave_Rad_Flux_surface mean  \
# 0  31.0  254.0  1994-01-01                              367.065219
# 1  31.0  254.0  1994-01-02                              368.057103
# 2  31.0  254.0  1994-01-03                              358.022946
# 3  31.0  254.0  1994-01-04                              366.386096
# 4  31.0  254.0  1994-01-05                              372.722521
#
#    Upward_Long-Wave_Rad_Flux_surface min  \
# 0                              324.00000
# 1                              329.00000
# 2                              309.02200
# 3                              318.54144
# 4                              321.57993
#
#    Upward_Long-Wave_Rad_Flux_surface std  \
# 0                              40.295247
# 1                              36.823085
# 2                              44.284551
# 3                              42.917750
# 4                              48.962837
#
#    Upward_Long-Wave_Rad_Flux_surface max  Upward_Short-Wave_Rad_Flux mean  \
# 0                              422.75583                        68.781818
# 1                              419.00000                        69.690909
# 2                              418.46637                        70.036364
# 3                              426.78842                        69.727273
# 4                              436.33432                        70.581818
#
#    Upward_Short-Wave_Rad_Flux min  Upward_Short-Wave_Rad_Flux std    ...     \
# 0                             0.0                       63.209438    ...
# 1                             0.0                       64.501184    ...
# 2                             0.0                       64.539383    ...
# 3                             0.0                       64.255985    ...
# 4                             0.0                       65.015010    ...
#
#    Upward_Long-Wave_Rad_Flux max  ens mean  ens min   ens std  ens max  \
# 0                      281.09550         5        0  3.191424       10
# 1                      278.86664         5        0  3.191424       10
# 2                      279.30950         5        0  3.191424       10
# 3                      282.80730         5        0  3.191424       10
# 4                      289.41656         5        0  3.191424       10
#
#    Pressure mean  Pressure min  Pressure std  Pressure max  datetime
# 0  102217.904727     101916.42    184.451255     102476.81  19940101
# 1  102173.175091     101924.96    153.622300     102467.37  19940102
# 2  102152.114182     101812.38    241.888780     102459.32  19940103
# 3  102382.628545     102041.37    166.193135     102632.57  19940104
# 4  101443.177091     100905.18    379.803869     101964.53  19940105
#
# [5 rows x 68 columns]

# %%
training_df = pd.merge(
    gefs_train_df,
    tmp_1_df[["datetime","station","distance_km","gefs_lat","gefs_lon","measured_solar_output"]],
    left_on=["lat", "lon", "datetime"],
    right_on=["gefs_lat", "gefs_lon", "datetime"],
    how="inner"
)

# %%
training_df.head()
# Out:
#     lat    lon        time  Upward_Long-Wave_Rad_Flux_surface mean  \
# 0  31.0  254.0  1994-01-01                              367.065219
# 1  31.0  254.0  1994-01-01                              367.065219
# 2  31.0  254.0  1994-01-01                              367.065219
# 3  31.0  254.0  1994-01-01                              367.065219
# 4  31.0  254.0  1994-01-01                              367.065219
#
#    Upward_Long-Wave_Rad_Flux_surface min  \
# 0                                  324.0
# 1                                  324.0
# 2                                  324.0
# 3                                  324.0
# 4                                  324.0
#
#    Upward_Long-Wave_Rad_Flux_surface std  \
# 0                              40.295247
# 1                              40.295247
# 2                              40.295247
# 3                              40.295247
# 4                              40.295247
#
#    Upward_Long-Wave_Rad_Flux_surface max  Upward_Short-Wave_Rad_Flux mean  \
# 0                              422.75583                        68.781818
# 1                              422.75583                        68.781818
# 2                              422.75583                        68.781818
# 3                              422.75583                        68.781818
# 4                              422.75583                        68.781818
#
#    Upward_Short-Wave_Rad_Flux min  Upward_Short-Wave_Rad_Flux std  \
# 0                             0.0                       63.209438
# 1                             0.0                       63.209438
# 2                             0.0                       63.209438
# 3                             0.0                       63.209438
# 4                             0.0                       63.209438
#
#            ...            Pressure mean  Pressure min  Pressure std  \
# 0          ...            102217.904727     101916.42    184.451255
# 1          ...            102217.904727     101916.42    184.451255
# 2          ...            102217.904727     101916.42    184.451255
# 3          ...            102217.904727     101916.42    184.451255
# 4          ...            102217.904727     101916.42    184.451255
#
#    Pressure max  datetime  station  distance_km  gefs_lat  gefs_lon  \
# 0     102476.81  19940101     ACME   856.245389      31.0     254.0
# 1     102476.81  19940101     ADAX   967.568287      31.0     254.0
# 2     102476.81  19940101     APAC   840.192442      31.0     254.0
# 3     102476.81  19940101     BIXB  1088.982975      31.0     254.0
# 4     102476.81  19940101     BLAC  1029.357771      31.0     254.0
#
#    measured_solar_output
# 0               12384900
# 1               11930700
# 2               12301200
# 3               11182800
# 4               10848300
#
# [5 rows x 73 columns]

# %%
training_df.to_csv("../data/daily_training_data_combined.csv", index=False)
